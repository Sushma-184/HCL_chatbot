# %%
#import necessary libraries
import os # for file path operations
import sys # for system-specific parameters and functions
import pandas as pd # for data manipulation
import numpy as np # for numerical operations
import matplotlib.pyplot as plt # for plotting
import seaborn as sns # for statistical data visualization

# imprt ML libraries
from sklearn.model_selection import train_test_split # for splitting data into training and testing sets
from sklearn.linear_model import LinearRegression # for linear regression model 
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score # for model evaluation metrics
from sklearn.preprocessing import StandardScaler # for feature scaling to keep the values between 0 and 1

#import popular ML models
from sklearn.ensemble import RandomForestRegressor # for random forest regression model
from sklearn.svm import SVR # for support vector regression model
from sklearn.tree import DecisionTreeRegressor # for decision tree regression model
from sklearn.neighbors import KNeighborsRegressor # for k-nearest neighbors regression model
from sklearn.neural_network import MLPRegressor # for multi-layer perceptron regression model
#Import Logistic Regression, SVM, LightGBM, and many more popular ones irrespective of tesk
from sklearn.linear_model import LogisticRegression # for logistic regression model
from sklearn.svm import SVC # for support vector classification model
from lightgbm import LGBMRegressor # for LightGBM regression model
from xgboost import XGBRegressor # for XGBoost regression model
# from catboost import CatBoostRegressor # for CatBoost regression model (not installed)
from sklearn.ensemble import GradientBoostingRegressor # for gradient boosting regression model
from sklearn.naive_bayes import GaussianNB # for Gaussian Naive Bayes classification model
from sklearn.naive_bayes import MultinomialNB # for Multinomial Naive Bayes classification model

# import warnings to ignore any warnings during execution
import warnings

from pysr import PySRRegressor # for symbolic regression model
